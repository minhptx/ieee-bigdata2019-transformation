# %%
import pandas as pd

import cufflinks as cf

import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from pymongo import MongoClient

from beakerx import *
from beakerx.object import beakerx

init_notebook_mode(connected=True)
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

beakerx.pandas_display_table()
client = MongoClient()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # This notebook shows the visualization of data transformation experiments

# %% [markdown]
# ## Active Learning Accuracy between IPBE and UDATA (sim or attr) are shown below.

# %%
import itertools
dataset_wth_alc = []

for dataset in ["ijcai", "sygus", "museum", "nyc", "prog"]:
     dataset_wth_alc.extend([
        {
            "method": x["config"]["mapping_method"],
            "acc": x["result"]["active_learning_curve"],
            "dataset": dataset,
        }
        for x in client.sacred.runs.find({"config.dataset": dataset})
    ])

df = pd.DataFrame(dataset_wth_alc)

# %%
df2 = df.set_index(["dataset", "method"])["acc"].apply(pd.Series).stack()
df2 = df2.reset_index().set_index(["dataset", "method"])
df2

# %%
df2.iplot(kind="scatter", subplots=True, subplot_titles=True, legend=False)
# Out:
# <div>
#
#
#             <div id="ed63fad9-046a-42c6-9662-1834de273897" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ed63fad9-046a-42c6-9662-1834de273897")) {
#                     Plotly.newPlot(
#                         'ed63fad9-046a-42c6-9662-1834de273897',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "method", "text": "", "type": "scatter", "uid": "c8545dc6-95dd-4c7f-9fb4-c432e98623a9", "x": ["ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "prog", "prog", "prog", "prog", "prog", "prog", "prog", "prog", "prog", "prog"], "xaxis": "x", "y": ["ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "sim", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe", "ipbe"], "yaxis": "y"}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "level_2", "text": "", "type": "scatter", "uid": "5956a372-e220-45c1-9943-5333d04b8ed0", "x": ["ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "ijcai", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "sygus", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "museum", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", "nyc", " ...
